# %% [markdown]
# # Two Pointers & Sliding Window
#
# ## Two Pointer Patterns
#
# **Opposite ends** — sorted array, palindrome check
# **Same direction** — remove duplicates, fast/slow
# **Sliding window** — subarray/substring with constraint
#
# **Template:**
# ```python
# left = 0
# for right in range(len(arr)):
#     # expand window
#     while invalid:
#         left += 1  # shrink
#     result = max(result, right - left + 1)
# ```

# %%
import sys; sys.path.insert(0,'..'); from src.two_pointers.two_pointers import *; from src.sliding_window.sliding_window import *

# %%
print('Two sum sorted:', two_sum_sorted([2,7,11,15], 9))
print('Move zeroes:', move_zeroes([0,1,0,3,12]))
print('Squares sorted:', squares_sorted([-4,-1,0,3,10]))
print('Is subsequence:', is_subsequence('abc','ahbgdc'))
# Out:
# Two sum sorted: [1, 2]
# Move zeroes: [1, 3, 12, 0, 0]
# Squares sorted: [0, 1, 9, 16, 100]
# Is subsequence: True

# %%
print('Max sum k=3:', max_sum_subarray_k([2,1,5,1,3,2], 3))
print('K distinct k=2:', longest_substring_k_distinct('eceba', 2))
print('Replacement k=1:', longest_repeating_replacement('AABABBA', 1))
print('Min subarray>=7:', min_size_subarray_sum([2,3,1,2,4,3], 7))
# Out:
# Max sum k=3: 9
# K distinct k=2: 3
# Replacement k=1: 4
# Min subarray>=7: 2
