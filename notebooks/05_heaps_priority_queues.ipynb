# %% [markdown]
# # Heaps & Priority Queues
#
# ## Heap Data Structure
#
# A complete binary tree where parent >= children (max-heap) or parent <= children (min-heap).
#
# **Operations:** push O(logn), pop O(logn), peek O(1), build O(n)
#
# **Applications:** Priority queues, scheduling, Dijkstra, top-K problems

# %%
import sys; sys.path.insert(0,'..'); from src.heaps.heap import *

# %%
h = MinHeap()
for v in [5,3,8,1,9,2,7]: h.push(v)
print('MinHeap peek:', h.peek)
vals = [h.pop() for _ in range(len(h))]
print('Pop order (sorted!):', vals)
# Out:
# MinHeap peek: 1
# Pop order (sorted!): [1, 2, 3, 5, 7, 8, 9]

# %%
print('Kth largest (k=2):', kth_largest([3,2,1,5,6,4], 2))
print('Top 2 frequent:', top_k_frequent([1,1,1,2,2,3], 2))
print('Merge k sorted:', merge_k_sorted([[1,4,7],[2,5,8],[3,6,9]]))
# Out:
# Kth largest (k=2): 5
# Top 2 frequent: [1, 2]
# Merge k sorted: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
mf = MedianFinder()
for n in [1,2,3,4,5,6]:
    mf.add_num(n)
    print(f'After {n}: median = {mf.find_median()}')
# Out:
# After 1: median = 1.0
# After 2: median = 1.5
# After 3: median = 2.0
# After 4: median = 2.5
# After 5: median = 3.0
# After 6: median = 3.5
