# %% [markdown]
# # String Algorithms — Patterns & Techniques
#
# ## String Algorithm Patterns
#
# 1. **Sliding Window** — substring problems
# 2. **Two Pointers** — palindrome, reversal
# 3. **Hash Map** — anagram, frequency
# 4. **KMP** — pattern matching O(n+m)
# 5. **Rabin-Karp** — rolling hash

# %%
import sys; sys.path.insert(0,'..'); from src.strings.string_algorithms import *

# %%
print('No repeat:', longest_substring_no_repeat('abcabcbb'))
print('Min window:', min_window_substring('ADOBECODEBANC','ABC'))
print('Anagram:', is_anagram('anagram','nagaram'))
# Out:
# No repeat: 3
# Min window: BANC
# Anagram: True

# %%
print('Group anagrams:', group_anagrams(['eat','tea','tan','ate','nat','bat']))
print('Longest palindrome:', longest_palindromic_substring('babad'))
print('KMP:', kmp_search('AABAACAADAABAABA','AABA'))
# Out:
# Group anagrams: [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
# Longest palindrome: bab
# KMP: [0, 9, 12]

# %%
print('Count palindromes:', count_palindromic_substrings('aaa'))
print('Common prefix:', longest_common_prefix(['flower','flow','flight']))
print('Inclusion:', check_inclusion('ab','eidbaooo'))
# Out:
# Count palindromes: 6
# Common prefix: fl
# Inclusion: True
