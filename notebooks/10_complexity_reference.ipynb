# %% [markdown]
# # Algorithm Complexity Reference
#
# ## Complete Complexity Reference
#
# This notebook provides a comprehensive reference for all algorithm complexities.

# %%
import pandas as pd

sorting = pd.DataFrame({
    'Algorithm': ['Bubble','Insertion','Selection','Merge','Quick','Heap','Counting','Radix'],
    'Best':      ['O(n)','O(n)','O(n²)','O(n logn)','O(n logn)','O(n logn)','O(n+k)','O(nk)'],
    'Average':   ['O(n²)','O(n²)','O(n²)','O(n logn)','O(n logn)','O(n logn)','O(n+k)','O(nk)'],
    'Worst':     ['O(n²)','O(n²)','O(n²)','O(n logn)','O(n²)','O(n logn)','O(n+k)','O(nk)'],
    'Space':     ['O(1)','O(1)','O(1)','O(n)','O(logn)','O(1)','O(k)','O(n+k)'],
    'Stable':    ['Yes','Yes','No','Yes','No','No','Yes','Yes'],
})
print("Sorting Algorithms:"); print(sorting.to_string(index=False))

# %%
ds = pd.DataFrame({
    'Structure':   ['Array','Linked List','Hash Table','BST','AVL Tree','Heap','Trie'],
    'Access':      ['O(1)','O(n)','N/A','O(logn)*','O(logn)','O(n)','N/A'],
    'Search':      ['O(n)','O(n)','O(1)*','O(logn)*','O(logn)','O(n)','O(L)'],
    'Insert':      ['O(n)','O(1)','O(1)*','O(logn)*','O(logn)','O(logn)','O(L)'],
    'Delete':      ['O(n)','O(1)','O(1)*','O(logn)*','O(logn)','O(logn)','O(L)'],
    'Space':       ['O(n)','O(n)','O(n)','O(n)','O(n)','O(n)','O(n·L)'],
})
print("\nData Structures:"); print(ds.to_string(index=False))

# %%
graph = pd.DataFrame({
    'Algorithm':   ['BFS','DFS','Dijkstra','Bellman-Ford','Floyd-Warshall','Kruskal MST','Prim MST','Topo Sort'],
    'Time':        ['O(V+E)','O(V+E)','O((V+E)logV)','O(VE)','O(V³)','O(E logE)','O(E logV)','O(V+E)'],
    'Space':       ['O(V)','O(V)','O(V)','O(V)','O(V²)','O(V)','O(V)','O(V)'],
    'Use Case':    ['Shortest (unweighted)','Cycle detect','SSSP (non-neg)','SSSP (neg)','All-pairs','MST','MST','DAG ordering'],
})
print("\nGraph Algorithms:"); print(graph.to_string(index=False))
